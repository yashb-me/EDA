# %%
#First five rows of the csv file
import pandas as pd
df = pd.read_csv('datasets/mtcars.csv')
df.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
#To print specific columns like model, mpg, cyl, hp and name of columns in one single cell
import pandas as pd
df = pd.read_csv('datasets/mtcars.csv')
display(df[['model', 'mpg', 'cyl', 'hp']])
print(df.columns)
# Out:
#                   model   mpg  cyl   hp
# 0             Mazda RX4  21.0    6  110
# 1         Mazda RX4 Wag  21.0    6  110
# 2            Datsun 710  22.8    4   93
# 3        Hornet 4 Drive  21.4    6  110
# 4     Hornet Sportabout  18.7    8  175
# 5               Valiant  18.1    6  105
# 6            Duster 360  14.3    8  245
# 7             Merc 240D  24.4    4   62
# 8              Merc 230  22.8    4   95
# 9              Merc 280  19.2    6  123
# 10            Merc 280C  17.8    6  123
# 11           Merc 450SE  16.4    8  180
# 12           Merc 450SL  17.3    8  180
# 13          Merc 450SLC  15.2    8  180
# 14   Cadillac Fleetwood  10.4    8  205
# 15  Lincoln Continental  10.4    8  215
# 16    Chrysler Imperial  14.7    8  230
# 17             Fiat 128  32.4    4   66
# 18          Honda Civic  30.4    4   52
# 19       Toyota Corolla  33.9    4   65
# 20        Toyota Corona  21.5    4   97
# 21     Dodge Challenger  15.5    8  150
# ...

# %%
#Now print the column names
import pandas as pd
df = pd.read_csv('datasets/mtcars.csv')
df.columns
# Out:
# ['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']

# %%
#To print all the rows where cyl is 8
import pandas as pd
df = pd.read_csv('datasets/mtcars.csv')
df[df['cyl'] == 8]
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0     3     3
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0     3     4
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0     3     4
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0     3     4
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   0     3     2
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0     3     2
# ...

# %%
#To print specific attributes
import pandas as pd
df = pd.read_csv('datasets/mtcars.csv')
print(df[['model', 'mpg', 'cyl', 'hp', 'wt']])
# Out:
#                   model   mpg  cyl   hp     wt
# 0             Mazda RX4  21.0    6  110  2.620
# 1         Mazda RX4 Wag  21.0    6  110  2.875
# 2            Datsun 710  22.8    4   93  2.320
# 3        Hornet 4 Drive  21.4    6  110  3.215
# 4     Hornet Sportabout  18.7    8  175  3.440
# 5               Valiant  18.1    6  105  3.460
# 6            Duster 360  14.3    8  245  3.570
# 7             Merc 240D  24.4    4   62  3.190
# 8              Merc 230  22.8    4   95  3.150
# 9              Merc 280  19.2    6  123  3.440
# 10            Merc 280C  17.8    6  123  3.440
# 11           Merc 450SE  16.4    8  180  4.070
# 12           Merc 450SL  17.3    8  180  3.730
# 13          Merc 450SLC  15.2    8  180  3.780
# 14   Cadillac Fleetwood  10.4    8  205  5.250
# 15  Lincoln Continental  10.4    8  215  5.424
# 16    Chrysler Imperial  14.7    8  230  5.345
# 17             Fiat 128  32.4    4   66  2.200
# 18          Honda Civic  30.4    4   52  1.615
# ...

# %%
#Sorting data based on one column (mpg)
import pandas as pd
df = pd.read_csv('datasets/mtcars.csv')
df.sort_values('mpg')
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0     3     4
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0     3     4
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0     3     4
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0     3     4
# 30        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1     5     8
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0     3     3
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0     3     2
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   0     3     2
# 28       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1     5     4
# ...

# %%
#Print unique cyl values
import pandas as pd
df = pd.read_csv('datasets/mtcars.csv')
df['cyl'].unique()
# Out:
# [6 4 8]

# %%
#To print count,mean,standard deviation,minimum,maximum and percentiles all at once
import pandas as pd
df = pd.read_csv('datasets/mtcars.csv')
df.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt       qsec         vs         am       gear     carb
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250  17.848750   0.437500   0.406250   3.687500   2.8125
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457   1.786943   0.504016   0.498991   0.737804   1.6152
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000  14.500000   0.000000   0.000000   3.000000   1.0000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250  16.892500   0.000000   0.000000   3.000000   2.0000
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000  17.710000   0.000000   0.000000   4.000000   2.0000
# ...

# %%
#To print rows matching certain conditions
import pandas as pd
df = pd.read_csv('datasets/mtcars.csv')
df[(df['cyl'] == 8) & (df['am'] == 1)]
# Out:
#              model   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  carb
# 28  Ford Pantera L  15.8    8  351.0  264  4.22  3.17  14.5   0   1     5     4
# 30   Maserati Bora  15.0    8  301.0  335  3.54  3.57  14.6   0   1     5     8

# %%
#To use group-by function and find the average value based on a particular group for example cyl
import pandas as pd
df = pd.read_csv('datasets/mtcars.csv')
df.groupby('cyl').mean(numeric_only=True)
# Out:
#            mpg        disp          hp      drat        wt       qsec        vs        am      gear      carb
# cyl
# 4    26.663636  105.136364   82.636364  4.070909  2.285727  19.137273  0.909091  0.727273  4.090909  1.545455
# 6    19.742857  183.314286  122.285714  3.585714  3.117143  17.977143  0.571429  0.428571  3.857143  3.428571
# 8    15.100000  353.100000  209.214286  3.229286  3.999214  16.772143  0.000000  0.142857  3.285714  3.500000

# %%
#To print specific rows and specific columns at once using index
import pandas as pd
df = pd.read_csv('datasets/mtcars.csv')
df.iloc[0:3, 0:4]
# Out:
#            model   mpg  cyl   disp
# 0      Mazda RX4  21.0    6  160.0
# 1  Mazda RX4 Wag  21.0    6  160.0
# 2     Datsun 710  22.8    4  108.0

# %%
#To print specific rows and columns based on names of rows and columns
import pandas as pd
df = pd.read_csv('datasets/mtcars.csv')
df.loc[0:2, ['model', 'mpg', 'cyl', 'hp']]
# Out:
#            model   mpg  cyl   hp
# 0      Mazda RX4  21.0    6  110
# 1  Mazda RX4 Wag  21.0    6  110
# 2     Datsun 710  22.8    4   93

# %%
#To print the model and mpg of rows whose values have cyl as 4
import pandas as pd
df = pd.read_csv('datasets/mtcars.csv')
df[df['cyl'] == 4][['model', 'mpg']]
# Out:
#              model   mpg
# 2       Datsun 710  22.8
# 7        Merc 240D  24.4
# 8         Merc 230  22.8
# 17        Fiat 128  32.4
# 18     Honda Civic  30.4
# 19  Toyota Corolla  33.9
# 20   Toyota Corona  21.5
# 25       Fiat X1-9  27.3
# 26   Porsche 914-2  26.0
# 27    Lotus Europa  30.4
# 31      Volvo 142E  21.4

# %%
#To rename columns of the csv file
import pandas as pd
df = pd.read_csv('datasets/mtcars.csv')
df.rename(columns={'model': 'Car_Model', 'mpg': 'Miles_Per_Gallon'}, inplace=True)
df.head()
# Out:
#            Car_Model  Miles_Per_Gallon  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0          Mazda RX4              21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1      Mazda RX4 Wag              21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2         Datsun 710              22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3     Hornet 4 Drive              21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  Hornet Sportabout              18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
#To drop a column
import pandas as pd
df = pd.read_csv('datasets/mtcars.csv')
df.drop('carb', axis=1, inplace=True)
df.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
