# %% [markdown]
# # Lab Assessment 1 - EDA Coursework
#
# **Reference:** Kaushikraviiyer/EDA-Coursework/Lab_Assessment-1.ipynb
# **Dataset:** restaurants.csv (15 pandas exercises)
#
# ---

# %%
# Exercise 1: First five rows of the csv file
import pandas as pd

df = pd.read_csv('/tmp/restaurants.csv')
df.head()

# %%
# Exercise 2: Print specific columns - Restaurant_ID, Name, City, State, Country and column names
import pandas as pd

df = pd.read_csv('/tmp/restaurants.csv')
display(df[['Restaurant_ID', 'Name', 'City', 'State', 'Country']])

print(df.columns)

# %%
# Exercise 3: Print all column names
import pandas as pd

df = pd.read_csv('/tmp/restaurants.csv')
df.columns

# %%
# Exercise 4: Print all rows where State name is Morelos
import pandas as pd

df = pd.read_csv('/tmp/restaurants.csv')
df[df['State'] == 'Morelos']

# %%
# Exercise 5: Print specific attributes - shape, size, ndim, len
import pandas as pd

df = pd.read_csv('/tmp/restaurants.csv')

print(df.shape)  # Number of rows and columns
print(df.size)   # Number of datapoints in the dataset
print(df.ndim)   # Number of dimensions
print(len(df))   # Number of rows

# %%
# Exercise 6: Sorting data based on one column (Name)
import pandas as pd

df = pd.read_csv('/tmp/restaurants.csv')
df.sort_values(by='Name')

# %%
# Exercise 7: Print unique city names
import pandas as pd

df = pd.read_csv('/tmp/restaurants.csv')
df['City'].unique()

# %%
# Exercise 8: Print count, mean, standard deviation, minimum, maximum and percentiles
import pandas as pd

df = pd.read_csv('/tmp/restaurants.csv')
df.describe()

# %%
# Exercise 9: Print rows matching certain conditions - State is Morelos AND City is Cuernavaca
import pandas as pd

df = pd.read_csv('/tmp/restaurants.csv')
df[(df['State'] == 'Morelos') & (df['City'] == 'Cuernavaca')]

# %%
# Exercise 10: Use group-by function and find average value based on a particular group (State)
import pandas as pd

df = pd.read_csv('/tmp/restaurants.csv')
df.groupby('State').mean(numeric_only=True)

# %%
# Exercise 11: Print specific rows and specific columns at once using index (iloc)
import pandas as pd

df = pd.read_csv('/tmp/restaurants.csv')
df.iloc[0:3, 0:2]

# %%
# Exercise 12: Print specific rows and columns based on names (loc)
import pandas as pd

df = pd.read_csv('/tmp/restaurants.csv')
df.loc[0:4, ['Name', 'State']]

# %%
# Exercise 13: Print Name and City of rows whose State is Tamaulipas
import pandas as pd

df = pd.read_csv('/tmp/restaurants.csv')
df.loc[df['State'] == 'Tamaulipas', ['Name', 'City']]

# %%
# Exercise 14: Rename columns of the csv file
import pandas as pd

df = pd.read_csv('/tmp/restaurants.csv')
df.rename(columns={'Name': 'Restaurant_Name', 'City': 'Location_City'}, inplace=True)
df.head()

# %%
# Exercise 15: Drop a column
import pandas as pd

df = pd.read_csv('/tmp/restaurants.csv')
df.drop('Area', axis=1, inplace=True)
df.head()
