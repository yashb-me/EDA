# %%
#First five rows of the csv file
import pandas as pd
df = pd.read_csv('datasets/restaurants.csv')
df.head()
# Out:
#    Restaurant_ID                Name             City            State Country  Zip_Code   Latitude   Longitude  Alcohol_Service Smoking_Allowed Price Franchise    Area Parking
# 0         132560  Puesto de Gorditas  Ciudad Victoria       Tamaulipas  Mexico       NaN  23.752304  -99.166913              NaN             Yes   Low        No    Open  Public
# 1         132561          Cafe Ambar  Ciudad Victoria       Tamaulipas  Mexico       NaN  23.726819  -99.126506              NaN              No   Low        No  Closed     NaN
# 2         132564            Church's  Ciudad Victoria       Tamaulipas  Mexico       NaN  23.730925  -99.145185              NaN              No   Low        No  Closed     NaN
# 3         132572        Cafe Chaires  San Luis Potosi  San Luis Potosi  Mexico       NaN  22.141647 -100.992712              NaN              No   Low        No  Closed     Yes
# 4         132583    McDonalds Centro       Cuernavaca          Morelos  Mexico   62000.0  18.922290  -99.234332              NaN              No   Low       Yes  Closed     NaN

# %%
#To print specific columns like restaurant ID,City,State and Country and name of columns in one single cell
import pandas as pd
df = pd.read_csv('datasets/restaurants.csv')
display(df[['Restaurant_ID', 'Name', 'City','State','Country']])
print(df.columns)
# Out:
#     Restaurant_ID                Name             City            State Country
# 0          132560  Puesto de Gorditas  Ciudad Victoria       Tamaulipas  Mexico
# 1          132561          Cafe Ambar  Ciudad Victoria       Tamaulipas  Mexico
# 2          132564            Church's  Ciudad Victoria       Tamaulipas  Mexico
# 3          132572        Cafe Chaires  San Luis Potosi  San Luis Potosi  Mexico
# 4          132583    McDonalds Centro       Cuernavaca          Morelos  Mexico
# 5          132591               Wings       Cuernavaca          Morelos  Mexico
# 6          132594             Wings 2       Cuernavaca          Morelos  Mexico
# 7          132597             Wings 3       Cuernavaca          Morelos  Mexico
# 8          132600             Wings 4       Cuernavaca          Morelos  Mexico
# 9          132603             Wings 5       Cuernavaca          Morelos  Mexico
# 10         132606             Wings 6       Cuernavaca          Morelos  Mexico
# 11         132609             Wings 7       Cuernavaca          Morelos  Mexico
# 12         132612             Wings 8       Cuernavaca          Morelos  Mexico
# 13         132615             Wings 9       Cuernavaca          Morelos  Mexico
# 14         132618            Wings 10       Cuernavaca          Morelos  Mexico
# 15         132621            Wings 11       Cuernavaca          Morelos  Mexico
# 16         132624            Wings 12       Cuernavaca          Morelos  Mexico
# 17         132627            Wings 13       Cuernavaca          Morelos  Mexico
# 18         132630            Wings 14       Cuernavaca          Morelos  Mexico
# 19         132633            Wings 15       Cuernavaca          Morelos  Mexico
#
# ['Restaurant_ID', 'Name', 'City', 'State', 'Country', 'Zip_Code', 'Latitude', 'Longitude', 'Alcohol_Service', 'Smoking_Allowed', 'Price', 'Franchise', 'Area', 'Parking']

# %%
#Now print the column names
import pandas as pd
df = pd.read_csv('datasets/restaurants.csv')
df.columns
# Out:
# ['Restaurant_ID', 'Name', 'City', 'State', 'Country', 'Zip_Code', 'Latitude', 'Longitude', 'Alcohol_Service', 'Smoking_Allowed', 'Price', 'Franchise', 'Area', 'Parking']

# %%
#To print all the rows where State name is Morelos
import pandas as pd
df = pd.read_csv('datasets/restaurants.csv')
df[df['State']=='Morelos']
# Out:
#     Restaurant_ID              Name        City    State Country  Zip_Code   Latitude  Longitude  Alcohol_Service Smoking_Allowed Price Franchise    Area Parking
# 4          132583  McDonalds Centro  Cuernavaca  Morelos  Mexico   62000.0  18.922290 -99.234332              NaN              No   Low       Yes  Closed     NaN
# 5          132591             Wings  Cuernavaca  Morelos  Mexico   62000.0  18.923425 -99.213225              NaN              No   Low        No  Closed     NaN
# 6          132594           Wings 2  Cuernavaca  Morelos  Mexico   62000.0  18.905325 -99.165725              NaN              No   Low        No  Closed     NaN
# 7          132597           Wings 3  Cuernavaca  Morelos  Mexico   62000.0  18.903325 -99.161725              NaN              No   Low        No  Closed     NaN
# 8          132600           Wings 4  Cuernavaca  Morelos  Mexico   62000.0  18.901325 -99.157725              NaN              No   Low        No  Closed     NaN
# 9          132603           Wings 5  Cuernavaca  Morelos  Mexico   62000.0  18.899325 -99.153725              NaN              No   Low        No  Closed     NaN
# 10         132606           Wings 6  Cuernavaca  Morelos  Mexico   62000.0  18.897325 -99.149725              NaN              No   Low        No  Closed     NaN
# 11         132609           Wings 7  Cuernavaca  Morelos  Mexico   62000.0  18.895325 -99.145725              NaN              No   Low        No  Closed     NaN
# 12         132612           Wings 8  Cuernavaca  Morelos  Mexico   62000.0  18.893325 -99.141725              NaN              No   Low        No  Closed     NaN
# 13         132615           Wings 9  Cuernavaca  Morelos  Mexico   62000.0  18.891325 -99.137725              NaN              No   Low        No  Closed     NaN
# 14         132618          Wings 10  Cuernavaca  Morelos  Mexico   62000.0  18.889325 -99.133725              NaN              No   Low        No  Closed     NaN
# 15         132621          Wings 11  Cuernavaca  Morelos  Mexico   62000.0  18.887325 -99.129725              NaN              No   Low        No  Closed     NaN
# 16         132624          Wings 12  Cuernavaca  Morelos  Mexico   62000.0  18.885325 -99.125725              NaN              No   Low        No  Closed     NaN
# 17         132627          Wings 13  Cuernavaca  Morelos  Mexico   62000.0  18.883325 -99.121725              NaN              No   Low        No  Closed     NaN
# 18         132630          Wings 14  Cuernavaca  Morelos  Mexico   62000.0  18.881325 -99.117725              NaN              No   Low        No  Closed     NaN
# 19         132633          Wings 15  Cuernavaca  Morelos  Mexico   62000.0  18.879325 -99.113725              NaN              No   Low        No  Closed     NaN

# %%
#To print specific attributes
import pandas as pd
df = pd.read_csv('datasets/restaurants.csv')
print(df.shape) #To print number of rows and columns 
print(df.size) #To print the number of datapoints in the dataset
print(df.ndim) #To show how many dimensions is the table
len(df) #To print the number of rows
# Out:
# (20, 14)
# 280
# 2
# 20

# %%
#Sorting data based on one column(Name)
import pandas as pd
df = pd.read_csv('datasets/restaurants.csv')
df.sort_values(by='Name')
# Out:
#     Restaurant_ID                Name             City            State Country  Zip_Code   Latitude   Longitude  Alcohol_Service Smoking_Allowed Price Franchise    Area Parking
# 1          132561          Cafe Ambar  Ciudad Victoria       Tamaulipas  Mexico       NaN  23.726819  -99.126506              NaN              No   Low        No  Closed     NaN
# 3          132572        Cafe Chaires  San Luis Potosi  San Luis Potosi  Mexico       NaN  22.141647 -100.992712              NaN              No   Low        No  Closed     Yes
# 2          132564            Church's  Ciudad Victoria       Tamaulipas  Mexico       NaN  23.730925  -99.145185              NaN              No   Low        No  Closed     NaN
# 4          132583    McDonalds Centro       Cuernavaca          Morelos  Mexico   62000.0  18.922290  -99.234332              NaN              No   Low       Yes  Closed     NaN
# 0          132560  Puesto de Gorditas  Ciudad Victoria       Tamaulipas  Mexico       NaN  23.752304  -99.166913              NaN             Yes   Low        No    Open  Public
# 5          132591               Wings       Cuernavaca          Morelos  Mexico   62000.0  18.923425  -99.213225              NaN              No   Low        No  Closed     NaN
# 14         132618            Wings 10       Cuernavaca          Morelos  Mexico   62000.0  18.889325  -99.133725              NaN              No   Low        No  Closed     NaN
# 15         132621            Wings 11       Cuernavaca          Morelos  Mexico   62000.0  18.887325  -99.129725              NaN              No   Low        No  Closed     NaN
# 16         132624            Wings 12       Cuernavaca          Morelos  Mexico   62000.0  18.885325  -99.125725              NaN              No   Low        No  Closed     NaN
# 17         132627            Wings 13       Cuernavaca          Morelos  Mexico   62000.0  18.883325  -99.121725              NaN              No   Low        No  Closed     NaN
# 18         132630            Wings 14       Cuernavaca          Morelos  Mexico   62000.0  18.881325  -99.117725              NaN              No   Low        No  Closed     NaN
# 19         132633            Wings 15       Cuernavaca          Morelos  Mexico   62000.0  18.879325  -99.113725              NaN              No   Low        No  Closed     NaN
# 6          132594             Wings 2       Cuernavaca          Morelos  Mexico   62000.0  18.905325  -99.165725              NaN              No   Low        No  Closed     NaN
# 7          132597             Wings 3       Cuernavaca          Morelos  Mexico   62000.0  18.903325  -99.161725              NaN              No   Low        No  Closed     NaN
# 8          132600             Wings 4       Cuernavaca          Morelos  Mexico   62000.0  18.901325  -99.157725              NaN              No   Low        No  Closed     NaN
# 9          132603             Wings 5       Cuernavaca          Morelos  Mexico   62000.0  18.899325  -99.153725              NaN              No   Low        No  Closed     NaN
# 10         132606             Wings 6       Cuernavaca          Morelos  Mexico   62000.0  18.897325  -99.149725              NaN              No   Low        No  Closed     NaN
# 11         132609             Wings 7       Cuernavaca          Morelos  Mexico   62000.0  18.895325  -99.145725              NaN              No   Low        No  Closed     NaN
# 12         132612             Wings 8       Cuernavaca          Morelos  Mexico   62000.0  18.893325  -99.141725              NaN              No   Low        No  Closed     NaN
# 13         132615             Wings 9       Cuernavaca          Morelos  Mexico   62000.0  18.891325  -99.137725              NaN              No   Low        No  Closed     NaN

# %%
#Print unique city names
import pandas as pd
df = pd.read_csv('datasets/restaurants.csv')
df['City'].unique()
# Out:
# ['Ciudad Victoria' 'San Luis Potosi' 'Cuernavaca']

# %%
#To print count,mean,standard deviation,minimum,maximum and percentiles all at once
import pandas as pd
df = pd.read_csv('datasets/restaurants.csv')
df.describe()
# Out:
#         Restaurant_ID                Name        City    State Country  Zip_Code   Latitude   Longitude  Alcohol_Service Smoking_Allowed Price Franchise    Area Parking
# count       20.000000                  20          20       20      20      16.0  20.000000   20.000000              0.0              20    20        20      20       2
# unique            NaN                  20           3        3       1       NaN        NaN         NaN              NaN               2     1         2       2       2
# top               NaN  Puesto de Gorditas  Cuernavaca  Morelos  Mexico       NaN        NaN         NaN              NaN              No   Low        No  Closed  Public
# freq              NaN                   1          16       16      20       NaN        NaN         NaN              NaN              19    20        19      19       1
# mean    132601.000000                 NaN         NaN      NaN     NaN   62000.0  19.784498  -99.241751              NaN             NaN   NaN       NaN     NaN     NaN
# std         23.112995                 NaN         NaN      NaN     NaN       0.0   1.850252    0.413223              NaN             NaN   NaN       NaN     NaN     NaN
# min     132560.000000                 NaN         NaN      NaN     NaN   62000.0  18.879325 -100.992712              NaN             NaN   NaN       NaN     NaN     NaN
# 25%     132589.000000                 NaN         NaN      NaN     NaN   62000.0  18.888825  -99.162725              NaN             NaN   NaN       NaN     NaN     NaN
# 50%     132604.500000                 NaN         NaN      NaN     NaN   62000.0  18.898325  -99.145455              NaN             NaN   NaN       NaN     NaN     NaN
# 75%     132618.750000                 NaN         NaN      NaN     NaN   62000.0  18.922574  -99.128920              NaN             NaN   NaN       NaN     NaN     NaN
# max     132633.000000                 NaN         NaN      NaN     NaN   62000.0  23.752304  -99.113725              NaN             NaN   NaN       NaN     NaN     NaN

# %%
#To print rows matching certain conditions
import pandas as pd
df = pd.read_csv('datasets/restaurants.csv')
df[(df['State'] == 'Morelos') & (df['City'] == 'Cuernavaca')]
# Out:
#     Restaurant_ID              Name        City    State Country  Zip_Code   Latitude  Longitude  Alcohol_Service Smoking_Allowed Price Franchise    Area Parking
# 4          132583  McDonalds Centro  Cuernavaca  Morelos  Mexico   62000.0  18.922290 -99.234332              NaN              No   Low       Yes  Closed     NaN
# 5          132591             Wings  Cuernavaca  Morelos  Mexico   62000.0  18.923425 -99.213225              NaN              No   Low        No  Closed     NaN
# 6          132594           Wings 2  Cuernavaca  Morelos  Mexico   62000.0  18.905325 -99.165725              NaN              No   Low        No  Closed     NaN
# 7          132597           Wings 3  Cuernavaca  Morelos  Mexico   62000.0  18.903325 -99.161725              NaN              No   Low        No  Closed     NaN
# 8          132600           Wings 4  Cuernavaca  Morelos  Mexico   62000.0  18.901325 -99.157725              NaN              No   Low        No  Closed     NaN
# 9          132603           Wings 5  Cuernavaca  Morelos  Mexico   62000.0  18.899325 -99.153725              NaN              No   Low        No  Closed     NaN
# 10         132606           Wings 6  Cuernavaca  Morelos  Mexico   62000.0  18.897325 -99.149725              NaN              No   Low        No  Closed     NaN
# 11         132609           Wings 7  Cuernavaca  Morelos  Mexico   62000.0  18.895325 -99.145725              NaN              No   Low        No  Closed     NaN
# 12         132612           Wings 8  Cuernavaca  Morelos  Mexico   62000.0  18.893325 -99.141725              NaN              No   Low        No  Closed     NaN
# 13         132615           Wings 9  Cuernavaca  Morelos  Mexico   62000.0  18.891325 -99.137725              NaN              No   Low        No  Closed     NaN
# 14         132618          Wings 10  Cuernavaca  Morelos  Mexico   62000.0  18.889325 -99.133725              NaN              No   Low        No  Closed     NaN
# 15         132621          Wings 11  Cuernavaca  Morelos  Mexico   62000.0  18.887325 -99.129725              NaN              No   Low        No  Closed     NaN
# 16         132624          Wings 12  Cuernavaca  Morelos  Mexico   62000.0  18.885325 -99.125725              NaN              No   Low        No  Closed     NaN
# 17         132627          Wings 13  Cuernavaca  Morelos  Mexico   62000.0  18.883325 -99.121725              NaN              No   Low        No  Closed     NaN
# 18         132630          Wings 14  Cuernavaca  Morelos  Mexico   62000.0  18.881325 -99.117725              NaN              No   Low        No  Closed     NaN
# 19         132633          Wings 15  Cuernavaca  Morelos  Mexico   62000.0  18.879325 -99.113725              NaN              No   Low        No  Closed     NaN

# %%
#To use group-by function and find the average value based on a particular group for example state
import pandas as pd
df = pd.read_csv('datasets/restaurants.csv')
df.groupby('State').mean(numeric_only=True)
# Out:
#                  Restaurant_ID  Zip_Code   Latitude   Longitude  Alcohol_Service
# State
# Morelos          132610.187500   62000.0  18.896142  -99.150232              NaN
# San Luis Potosi  132572.000000       NaN  22.141647 -100.992712              NaN
# Tamaulipas       132561.666667       NaN  23.736683  -99.146201              NaN

# %%
#To print specific rows and specific columns at once using index
import pandas as pd
df = pd.read_csv('datasets/restaurants.csv')
df.iloc[0:3, 0:2]
# Out:
#    Restaurant_ID                Name
# 0         132560  Puesto de Gorditas
# 1         132561          Cafe Ambar
# 2         132564            Church's

# %%
#To print specific rows and columns based on names of rows and columns
import pandas as pd
df = pd.read_csv('datasets/restaurants.csv')
df.loc[0:4, ['Name', 'State']]
# Out:
#                  Name            State
# 0  Puesto de Gorditas       Tamaulipas
# 1          Cafe Ambar       Tamaulipas
# 2            Church's       Tamaulipas
# 3        Cafe Chaires  San Luis Potosi
# 4    McDonalds Centro          Morelos

# %%
#To print the Name and City of rows whose values have state as Tamaulipas
import pandas as pd
df = pd.read_csv('datasets/restaurants.csv')
df.loc[df['State'] == 'Tamaulipas', ['Name', 'City']]
# Out:
#                  Name             City
# 0  Puesto de Gorditas  Ciudad Victoria
# 1          Cafe Ambar  Ciudad Victoria
# 2            Church's  Ciudad Victoria

# %%
#To rename columns of the csv file
import pandas as pd
df = pd.read_csv('datasets/restaurants.csv')
df.rename(columns={'Name': 'Restaurant_Name', 'City': 'Location_City'}, inplace=True)
df.head()
# Out:
#    Restaurant_ID     Restaurant_Name    Location_City            State Country  Zip_Code   Latitude   Longitude  Alcohol_Service Smoking_Allowed Price Franchise    Area Parking
# 0         132560  Puesto de Gorditas  Ciudad Victoria       Tamaulipas  Mexico       NaN  23.752304  -99.166913              NaN             Yes   Low        No    Open  Public
# 1         132561          Cafe Ambar  Ciudad Victoria       Tamaulipas  Mexico       NaN  23.726819  -99.126506              NaN              No   Low        No  Closed     NaN
# 2         132564            Church's  Ciudad Victoria       Tamaulipas  Mexico       NaN  23.730925  -99.145185              NaN              No   Low        No  Closed     NaN
# 3         132572        Cafe Chaires  San Luis Potosi  San Luis Potosi  Mexico       NaN  22.141647 -100.992712              NaN              No   Low        No  Closed     Yes
# 4         132583    McDonalds Centro       Cuernavaca          Morelos  Mexico   62000.0  18.922290  -99.234332              NaN              No   Low       Yes  Closed     NaN

# %%
#To drop a column
import pandas as pd
df = pd.read_csv('datasets/restaurants.csv')
df.drop('Area', axis=1, inplace=True)
df.head()
# Out:
#    Restaurant_ID                Name             City            State Country  Zip_Code   Latitude   Longitude  Alcohol_Service Smoking_Allowed Price Franchise Parking
# 0         132560  Puesto de Gorditas  Ciudad Victoria       Tamaulipas  Mexico       NaN  23.752304  -99.166913              NaN             Yes   Low        No  Public
# 1         132561          Cafe Ambar  Ciudad Victoria       Tamaulipas  Mexico       NaN  23.726819  -99.126506              NaN              No   Low        No     NaN
# 2         132564            Church's  Ciudad Victoria       Tamaulipas  Mexico       NaN  23.730925  -99.145185              NaN              No   Low        No     NaN
# 3         132572        Cafe Chaires  San Luis Potosi  San Luis Potosi  Mexico       NaN  22.141647 -100.992712              NaN              No   Low        No     Yes
# 4         132583    McDonalds Centro       Cuernavaca          Morelos  Mexico   62000.0  18.922290  -99.234332              NaN              No   Low       Yes     NaN
